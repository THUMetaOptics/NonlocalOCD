# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from my_dataset import MyDataset
from Model3 import ResidualBlock, ICmosToThetaResNet, icmos_to_ms_resnet, weights_init
from theta2Ms import M_pol, R, M_wp
import torch
import torch.nn as nn
import torch.optim as optim
from PINN_optimization2 import PINN

# %% [markdown]
# # 测试90°

# %%
M_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\M_decoder.mat"
Sin_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\S_encoder.mat"
Spec_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250217\Alluse\spec.mat"

# 改变这一项来改变输出
I_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\Experi_data\I_wp90_polar90.mat"

# 开始优化
PINN_operator = PINN(M_path, Sin_path, Spec_path, I_path)

# %%
predicted_theta = PINN_operator.training(1e-5, 1e-6)
# Out:
# predicted theta is 90.2159

# %%
print(predicted_theta)
# Out:
# 90.21587371826172

# %% [markdown]
# # 测试150°

# %%
M_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\M_decoder.mat"
Sin_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\S_encoder.mat"
Spec_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250217\Alluse\spec.mat"

# 改变这一项来改变输出
I_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\Experi_data\I_wp90_polar150.mat"

# 开始优化
PINN_operator = PINN(M_path, Sin_path, Spec_path, I_path)

predicted_theta = PINN_operator.training(1e-5, 1e-6)

print(predicted_theta)
# Out:
# predicted theta is 156.2606
# 156.26063537597656

# %%
20855.64 % 180
# Out:
# 155.63999999999942

# %% [markdown]
# # 测试60°

# %%
M_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\M_decoder.mat"
Sin_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\S_encoder.mat"
Spec_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250217\Alluse\spec.mat"

# 改变这一项来改变输出
I_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\Experi_data\I_wp90_polar60.mat"

# 开始优化
PINN_operator = PINN(M_path, Sin_path, Spec_path, I_path)

predicted_theta = PINN_operator.training(1e-5, 1e-6)

print(predicted_theta)
# Out:
# predicted theta is 61.7638
# 61.76380157470703

# %% [markdown]
# # 测试45

# %%
M_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\M_decoder.mat"
Sin_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\S_encoder.mat"
Spec_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250217\Alluse\spec.mat"

# 改变这一项来改变输出
I_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\Experi_data\I_wp90_polar45.mat"

# 开始优化
PINN_operator = PINN(M_path, Sin_path, Spec_path, I_path)

predicted_theta = PINN_operator.training(1e-5, 1e-6)

print(predicted_theta)
# Out:
# predicted theta is 42.8789
# 42.87890625

# %% [markdown]
# # 测试30

# %%
M_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\M_decoder.mat"
Sin_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\S_encoder.mat"
Spec_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250217\Alluse\spec.mat"

# 改变这一项来改变输出
I_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250220\Experi_data\I_wp90_polar30.mat"

# 开始优化
PINN_operator = PINN(M_path, Sin_path, Spec_path, I_path)

predicted_theta = PINN_operator.training(1e-5, 1e-6)

print(predicted_theta)
# Out:
# predicted theta is 31.8300
# 31.830036163330078
