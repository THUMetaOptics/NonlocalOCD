# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from my_dataset import MyDataset
from Model3 import ResidualBlock, ICmosToThetaResNet, icmos_to_ms_resnet, weights_init
from theta2Ms import M_pol, R, M_wp
import torch
import torch.nn as nn
import torch.optim as optim
from PINN_optimization import PINN

# %% [markdown]
# # 测试90°

# %%
M_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/20250217/M_decoder.mat"
Sin_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/20250217/S_encoder.mat"
Spec_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250217\Alluse\spec.mat"

# 改变这一项来改变输出
I_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/Experi_Data/I_polar90.mat"

# 开始优化
PINN_operator = PINN(M_path, Sin_path, Spec_path, I_path)
initial_lr = 1e-4

# %%
predicted_theta = PINN_operator.training(1e-4, 1e-6)
# Out:
# step1: tensor([[91.]])
# step2: tensor([[87.0205]], grad_fn=<SqueezeBackward1>)
# Step3 predicted theta is 90.7781

# %%
print(predicted_theta % 180)
# Out:
# 90.778076171875

# %% [markdown]
# # 测试150°

# %%
M_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/20250217/M_decoder.mat"
Sin_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/20250217/S_encoder.mat"
Spec_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250217\Alluse\spec.mat"

# 改变这一项来改变输出
I_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/Experi_Data/I_polar150.mat"

# 开始优化
PINN_operator = PINN(M_path, Sin_path, Spec_path, I_path)
# 得到结果
predicted_theta = PINN_operator.training(1e-4, 1e-6)
print(predicted_theta)
# Out:
# step1: tensor([[154.]])
# step2: tensor([[146.1591]], grad_fn=<SqueezeBackward1>)
# Step3 predicted theta is 154.2248
# 154.22482299804688

# %%
predicted_theta % 180
# Out:
# 154.22482299804688

# %% [markdown]
# # 测试60°

# %%
M_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/20250217/M_decoder.mat"
Sin_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/20250217/S_encoder.mat"
Spec_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250217\Alluse\spec.mat"

# 改变这一项来改变输出
I_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/Experi_Data/I_polar60.mat"

# 开始优化
PINN_operator = PINN(M_path, Sin_path, Spec_path, I_path)
# 得到结果
predicted_theta = PINN_operator.training(1e-4, 1e-6)
print(predicted_theta)
# Out:
# step1: tensor([[64.]])
# step2: tensor([[60.8917]], grad_fn=<SqueezeBackward1>)
# Step3 predicted theta is 63.5590
# 63.558998107910156

# %% [markdown]
# # 测试45

# %%
M_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/20250217/M_decoder.mat"
Sin_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/20250217/S_encoder.mat"
Spec_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250217\Alluse\spec.mat"

# 改变这一项来改变输出
I_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/Experi_Data/I_polar45.mat"

# 开始优化
PINN_operator = PINN(M_path, Sin_path, Spec_path, I_path)
# 得到结果
predicted_theta = PINN_operator.training(1e-4, 1e-6)
print(predicted_theta)
# Out:
# step1: tensor([[16.]])
# step2: tensor([[16.0084]], grad_fn=<SqueezeBackward1>)
# Step3 predicted theta is 15.9430
# 15.942997932434082

# %% [markdown]
# # 测试30

# %%
M_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/20250217/M_decoder.mat"
Sin_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/20250217/S_encoder.mat"
Spec_path = r"F:\科研项目\XueXinyuan\D2M_plus\Datasets\Databasenew\20250217\Alluse\spec.mat"

# 改变这一项来改变输出
I_path = r"F:/科研项目/XueXinyuan/D2M_plus/Datasets/Databasenew/Experi_Data/I_polar30.mat"

# 开始优化
PINN_operator = PINN(M_path, Sin_path, Spec_path, I_path)
# 得到结果
predicted_theta = PINN_operator.training(1e-4, 1e-6)
print(predicted_theta)
# Out:
# step1: tensor([[26.]])
# step2: tensor([[26.7602]], grad_fn=<SqueezeBackward1>)
# Step3 predicted theta is 26.0927
# 26.092670440673828
